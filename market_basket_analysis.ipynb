# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
# !{sys.executable} -m pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from mlxtend) (2.2.6)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from mlxtend) (2.3.1)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from mlxtend) (1.7.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from mlxtend) (3.10.5)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ssc\miniconda3\envs\data_analysis\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)

# %%
import mlxtend
print(mlxtend.__version__)
# Out:
# 0.23.4

# %%
import sqlite3

# %%
import pandas as pd

# %%
from mlxtend.frequent_patterns import apriori, association_rules, fpgrowth

# %% [markdown]
# # Northwind Market Basket Analysis

# %%
conn = sqlite3.connect(r"D:\northwind_project\northwind-SQLite3-main\dist\northwind.db")

# %%
orders = pd.read_sql('SELECT * FROM Orders;', conn)
order_details = pd.read_sql('SELECT * FROM [Order Details];', conn)
products = pd.read_sql('SELECT * FROM Products;', conn)
categories = pd.read_sql('SELECT * FROM Categories;', conn)

# %%
conn.close()

# %%
df = order_details.merge(orders, on='OrderID', how='left')
df = df.merge(products, on='ProductID', how='left')
df = df.merge(categories, on='CategoryID', how='left')

# %%
df.dropna(subset=['ProductName'], inplace=True)
df.drop_duplicates(inplace=True)

# %%
basket_size = df.groupby('OrderID')['ProductID'].count()
print("Basket size description:\n", basket_size.describe())
# Out:
# Basket size description:
#  count    16282.000000
# mean        37.420649
# std         23.108610
# min          1.000000
# 25%         17.000000
# 50%         37.000000
# 75%         58.000000
# max         77.000000
# Name: ProductID, dtype: float64

# %%
top_products = df['ProductName'].value_counts().head(10)
print("Top products:\n", top_products)
# Out:
# Top products:
#  ProductName
# Louisiana Hot Spiced Okra     8040
# Teatime Chocolate Biscuits    8024
# Outback Lager                 8020
# Gumbär Gummibärchen           7999
# Sir Rodney's Marmalade        7999
# Gudbrandsdalsost              7991
# Raclette Courdavault          7982
# Ravioli Angelo                7969
# Konbu                         7968
# Gorgonzola Telino             7964
# Name: count, dtype: int64

# %%
top_categories = df['CategoryName'].value_counts()
print("Top categories:\n", top_categories)
# Out:
# Top categories:
#  CategoryName
# Confections       102784
# Beverages          95083
# Condiments         94988
# Seafood            94912
# Dairy Products     79233
# Grains/Cereals     55400
# Meat/Poultry       47335
# Produce            39548
# Name: count, dtype: int64

# %%
basket = df.groupby(['OrderID','ProductName'])['Quantity'].sum().unstack().fillna(0)
basket_binary = basket.applymap(lambda x: 1 if x>0 else 0)

# %%
# frequent_itemsets = apriori(basket_binary, min_support=0.02, use_colnames=True)

basket_binary = basket_binary.astype(bool)

frequent_itemsets = fpgrowth(
    basket_binary,
    min_support=0.05, 
    use_colnames=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 basket_binary = basket_binary.astype(bool)
# ----> 3 frequent_itemsets = fpgrowth(
#       4     basket_binary,
#       5     min_support=0.05,
#       6     use_colnames=True
#       7 )
#
# File c:\Users\ssc\miniconda3\envs\data_analysis\lib\site-packages\mlxtend\frequent_patterns\fpgrowth.py:95, in fpgrowth(df, min_support, null_values, use_colnames, max_len, verbose)
#      92 minsup = math.ceil(min_support * len(df.index))  # min support as count
#      93 generator = fpg_step(tree, minsup, colname_map, max_len, verbose)
# ---> 95 return fpc.generate_itemsets(
#      96     generator, df, disabled, min_support, len(df.index), colname_map
#      97 )
#
# File c:\Users\ssc\miniconda3\envs\data_analysis\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:93, in generate_itemsets(generator, df, disabled, min_support, num_itemsets, colname_map)
#      91 item_dsbl = list(dec[i, :])
#      92 # select the i-th iset from original dataset
# ---> 93 item_orig = list(_dec[i, :])
#      95 # check and keep count if there is a null value in iset of disabled
#      96 if 1 in set(item_dsbl):
#
# KeyboardInterrupt:

# %%
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1.0)
rules_filtered = rules[(rules['confidence']>0.4) & (rules['lift']>1.2)]
print("Filtered rules:\n", rules_filtered.head())

# %%
basket_cat = df.groupby(['OrderID','CategoryName'])['Quantity'].sum().unstack().fillna(0)
basket_cat_binary = basket_cat.applymap(lambda x: 1 if x>0 else 0)

# %%
frequent_cat = apriori(basket_cat_binary, min_support=0.05, use_colnames=True)
rules_cat = association_rules(frequent_cat, metric='lift', min_threshold=1.0)
rules_cat.sort_values('lift', ascending=False).head()

# %%
rules_filtered.to_csv('association_rules_products.csv', index=False)
rules_cat.to_csv('association_rules_categories.csv', index=False)
